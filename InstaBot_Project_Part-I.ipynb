# %% [markdown]
# # InstaBot Introduction - Part 1

# %% [markdown]
# Your friend has opened a new Food Blogging handle on Instagram and wants to get famous. He wants to follow a lot of people so that he can get noticed quickly but it is a tedious task so he asks you to help him. As you have just learned automation using Selenium, you decided to help him by creating an Instagram Bot.
# You need to create different functions for each task.

# %%
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException
from bs4 import BeautifulSoup
import time

# %%
#opening the browser, change the path as per location of chromedriver in your system
driver = webdriver.Chrome()
driver.maximize_window()

# %%
#opening instagram
driver.get('https://www.instagram.com/')

# %%
#update your username and password here
username = 'SAMPLE_USERNAME'
password = 'SAMPLE_PASSWORD'

# %%
#initializing  wait object
wait = WebDriverWait(driver, 10)

# %% [markdown]
# ### Problem 1 : Login to your Instagram
# Login to your Instagram Handle
# Submit with sample username and password

# %%
def LogIn(username, password):
    try :
        user_name = driver.find_element_by_name('username')
        user_name.send_keys(username)
        #locating password box and sending password
        pwd = driver.find_element_by_name('password')
        pwd.send_keys(password)
        #locating login button 
        button = wait.until(EC.presence_of_element_located((By.XPATH,'//div[contains(@class, "Igw0E")]//button[contains(@class, "sqdOP")]')))
        button.submit()
        #Save Your Login Info? : Not Now
        pop = wait.until(EC.presence_of_element_located((By.XPATH,'//div[contains(@class, "cmbtv")]//button[contains(@class, "sqdOP")]')))
        pop.click()
        #Turn on Notifications :Not Now
        pop1 = wait.until(EC.presence_of_element_located((By.XPATH,'//div[contains(@class, "mt3GC")]//button[contains(@class, "aOOlW")]')))
        pop1.click()
    except TimeoutException :
        print ("Something went wrong! Try Again")

# %%
#Login to your Instagram Handle
LogIn(username, password)

# %% [markdown]
# ### Problem 2 : Type for “food” in search bar
# Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”
# Note : Make sure to avoid printing hashtags

# %%
def search(s):
    try:
        #locating serch bar and sending text
        search_box = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'XTCLo')))
        search_box.send_keys(s)

        wait.until(EC.presence_of_element_located((By.CLASS_NAME,'-qQT3')))
        #extracting all serched handle
        handle_names = driver.find_elements_by_class_name('-qQT3')
        names = []
        #extracting username
        for i in handle_names :
            if i.text[0] != '#' :
                names.append(i.text.split('\n')[0])             

        time.sleep(5)
        #clearing search bar
        driver.find_element_by_class_name('coreSpriteSearchClear').click()
        
        return names
    
    except TimeoutException :
        print('No Search Found!')

# %%
#extracting all the names of the Instagram Handles that are displayed in list after typing “food” usimg search('food')
name_list = search('food')
for i in name_list :
    print(i)
# Out:
# foodie_incarnate
# ahmedabad__food
# the.food_cult
# yourfoodlab
# foodrush.recipe
# food_food_surat
# food
# desifood.blogger
# foodies.of.vadodara
# khana_khajana18
# foodporn
# streetfoodrecipe
# ahmedabad_food_trend
# foodofvadodara
# foodcoutureculinarycentre
# viwa_foodworld
# foodnetwork
# foodaddavastrapur
# food52
# thefoodbabe
# vadodarazfoodie
# __food_prism
# food_wackadoos
# foodaddasurat
# ahmedabad_food_blog
# foodbuzz.india
# foodadda1
# food.__.factory_
# foodsandflavorsbyshilpi
# food._hub_
# surat_eatery
# foodgod
# food_.gallery__
# food_fuel_vadodara
# _foodtoxic_
# ahm_foodiefriends
# ruchika_asatkar
# meghnasfoodmagic
# vadodara_foodiesisters
# foodcaptured_5
# foodfiesta_by_divya
# foodntraveljournal
# joohiie
# gujaratifoodiee
# foodie_surti_gj5
# _food__country
# foodmemories.official
# kbzfood_official
# Food Junction Grand Pakuwon
# food_for_tongue

# %% [markdown]
# ### Problem 3 : Searching and Opening a profile
# Searching and Opening a profile using
# Open profile of “So Delhi”

# %%
def search_open_profile(s):
    try:
        #locatong search box bar and sending text
        search_box = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'XTCLo')))
        search_box.send_keys(s)
        #locating serched result
        res = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'-qQT3')))
        res.click()           

        time.sleep(5)
        #driver.back()
    
    except TimeoutException :
        print('No Search Found!')

# %%
search_open_profile('So Delhi')

# %% [markdown]
# ### Problem 4 : Follow/Unfollow given handle
# Follow/Unfollow given handle -
# 1.Open the Instagram Handle of “So Delhi”
# 2.Start following it. Print a message if you are already following
# 3.After following, unfollow the instagram handle. Print a message if you have already unfollowed.

# %%
def follow():
    try :
        #locating follow button
        btn = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'_5f5mN')))
        #checking for text
        if btn.text == 'Follow' : 
            btn.click()
            time.sleep(3)
        
        else : 
            print('Already Following')

    except TimeoutException :
        print("Something Went Wrong!")

# %%
def unfollow():
    try :
        #locating follow button
        btn = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'_5f5mN')))
        #checking for text
        if btn.text !='Follow' : 
            btn.click()
            time.sleep(2)
            #locating popup window (when you click on follow button)
            pop_up = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'aOOlW')))
            pop_up.click()
            time.sleep(3)
            
        else : 
            print('Already Unfollowed')

    except TimeoutException :
        print("Something Went Wrong!")

# %%
#for search and open 'dilsefoodie' instagram handle
search_open_profile('So Delhi')
#for following this instgram handle
follow()
#for unfollowing this instgram handle
unfollow()

# %% [markdown]
# ### Problem 5 : Like/Unlike posts
# Like/Unlike posts
# 1.Liking the top 30 posts of the ‘dilsefoodie'. Print message if you have already liked it.
# 2.Unliking the top 30 posts of the ‘dilsefoodie’. Print message if you have already unliked it.

# %%
def Like_Post():
    try :
        #scrolling for locating post
        driver.execute_script('window.scrollTo(0, 6000);')
        time.sleep(3)
        driver.execute_script('window.scrollTo(0, -6000);')
        time.sleep(3)
        #locating post
        posts = driver.find_elements_by_class_name('v1Nh3')
        
        for i in range(30):
            posts[i].click()
            time.sleep(2)
            #locating like/unke button
            like = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'fr66n')))
            st = BeautifulSoup(like.get_attribute('innerHTML'),"html.parser").svg['aria-label']
            if st == 'Like' :
                like.click()
                time.sleep(2)
            if st == '#ed4956':
                print('You have already LIKED Post Number :', i+1)
                time.sleep(2)
            #locating cross button for closing post
            driver.find_element_by_class_name('yiMZG').click()
            time.sleep(2)
            
    except TimeoutException :
        print("Something Went Wrong!")

# %%
def Unlike_Post():
    try :
        #scrolling for locating post
        driver.execute_script('window.scrollTo(0, 6000);')
        time.sleep(3)
        driver.execute_script('window.scrollTo(0, -6000);')
        time.sleep(3)
        #locating post
        posts = driver.find_elements_by_class_name('v1Nh3')
     
        for i in range(30):
            posts[i].click()
            time.sleep(2)
            #locating like/unke button
            like = wait.until(EC.presence_of_element_located((By.CLASS_NAME,'fr66n')))
            st = BeautifulSoup(like.get_attribute('innerHTML'),"html.parser").svg['aria-label']
            if st == 'Unlike' :
                like.click()
                time.sleep(2)
            else :
                print('You have already UNLIKED Post Number', i+1)
                time.sleep(2)
            #locating cross button for closing post
            driver.find_element_by_class_name('yiMZG').click()
            time.sleep(2)
            
    except TimeoutException :
        print("Something Went Wrong!")

# %%
#for search and open 'dilsefoodie' instagram handle
search_open_profile('dilsefoodie')

# %%
#Liking the top 30 posts 
Like_Post()

# %%
#Unliking the top 30 posts 
Unlike_Post()

# %% [markdown]
# ### Problem 6 : Extract list of followers
# Extract list of followers
# 1.Extract the usernames of the first 500 followers of ‘foodtalkindia’ and ‘sodelhi’.
# 2.Now print all the followers of “foodtalkindia” that you are following but those who don’t follow you.

# %%
def Extract_Followers():
    try :
        # locating followers button and click on it
        followers_btn = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME,'g47SY')))
        followers_btn[1].click()
        
        #locating followers list
        frame = driver.find_element_by_class_name('isgrP')
        #scrolling untill first 500 user is located
        for i in range(50):
            time.sleep(1)
            driver.execute_script("arguments[0].scrollTop=arguments[0].scrollHeight",frame)
        
        names = []
        #extracting userdata
        followers = driver.find_elements_by_class_name('enpQJ')
        #extracting username
        for i in followers[:500] :
                names.append(i.text.split('\n')[0])
            
        return names
    except TimeoutException :
        print("Something Went Wrong!")

# %% [markdown]
# ##### First 500 followers of ‘foodtalkindia’

# %%
#for search and open 'foodtalkindia' instagram handle
search_open_profile('foodtalkindia')

# %%
# Extracting followers using Extract_Followers() function
users = Extract_Followers()
ind = 1
for username in users:
    print(ind,username)
    ind += 1
# Out:
# 1 motabhai_iswatchingyou
# 2 pikldbypushpa
# 3 shrvan_bishnoi2929
# 4 kille_rboy2570
# 5 abdurrehman4204
# 6 _hsayerh_
# 7 quotes_by_nitin
# 8 the_hungry_panda.shop
# 9 shaikh_shoaib_hussain
# 10 simonecosta81_
# 11 vnshika97
# 12 vireshwar_deshmukh
# 13 snaccindia
# 14 d_desirable_grl
# 15 _gulp_fiction_
# 16 mr_mahadev_ka_diwana5251
# 17 rajneesh_kumar22
# 18 h_s_016
# 19 usmani.anam
# 20 its_nandan_jha
# 21 dhairya143
# 22 tanusingh2010
# 23 lalitkk
# 24 nadiahamza348
# 25 s_k_singh_patel
# 26 bakeshwari
# 27 harshitasharma021
# 28 _rishabhsarkar
# 29 ccakeitup01
# 30 sangodkar_sau
# 31 singhal1596
# 32 sadafshah9
# 33 its_sagun_sk
# 34 gaytrikumari15330
# 35 pushpendra4130
# 36 the_patil
# 37 tryalongwithriya
# 38 jaipurdrinker
# 39 kkpl_theculinarylab
# 40 veagy37
# 41 arfin_shuvo445
# 42 pujapaulhalder
# 43 omimachoudhry
# 44 amanbhagat124
# 45 kumar_sanjeevx
# 46 salamanfrank
# 47 javedteepu
# 48 nishadkaran315
# 49 the_food_kaleidoscope
# 50 shagunsharma236
# 51 culture_fanatic
# 52 parlourhoney
# 53 fi.roj7358
# 54 mangeshwaghmare722
# 55 misty_biswas_cute_girl
# 56 aayushiiisharmaa
# 57 high_hippogriff
# 58 manisha_d_salunkhe
# 59 mrbadmas3
# 60 swada_odisha
# 61 traveller_indorianx
# 62 __foodgasm____
# 63 sid.veerwal
# 64 carla.sofia__
# 65 oye_badmash
# 66 sahid_follow_me
# 67 aanikaymanntaa
# 68 signalphotosphere
# 69 reels27271
# 70 debojit_mahit
# 71 reemablog
# 72 bake_with_khyati
# 73 faizeen_behlim
# 74 its_choudhary_sudhir
# 75 official_nisar_1
# 76 sjeanelimados
# 77 ravi__kukadiya
# 78 adibhattacharya
# 79 oh_angga
# 80 rakeshpuppala
# 81 nandita.singh1
# 82 rahichhabra
# 83 bentob.restaurant
# 84 gunitasingh
# 85 ayirp19
# 86 archana_sharma13
# 87 bombay_foodex
# 88 dr.kc.pediatric
# 89 the_viper_rko123
# 90 ___king__sam____
# 91 bengali.vlogger_rama
# 92 samriti_2022
# 93 sujata.mankar.18
# 94 varuny_salar
# 95 nanditachandola
# 96 raghavmehta581
# 97 jindaran_khan
# 98 ssaweeetie
# 99 geetanjali5
# 100 vie.salsa
# 101 masmasmasale
# 102 a_n_s_h_u_1502
# 103 snehaaloysius1999
# 104 mr_samad_ali_2
# 105 manideeptv
# 106 the_good_food_blog
# 107 sonalimahato09
# 108 rishi_with_h
# 109 laxmisharma8165
# 110 sr_752k
# 111 ritika._.78
# 112 ammulu_dathya
# 113 iamrakhidey
# 114 paramsharma.24
# 115 thelaughingbutter
# 116 bidawatkaayush
# 117 kolkatafoodtrek
# 118 foody_me0021
# 119 gaathaa_a_weavers_dream_
# 120 aayushbansal_
# 121 sulikerihanamant
# 122 singhniky
# 123 bittu_rabari380
# 124 srivahinistudios
# 125 karishma_dhamecha
# 126 _.imnandy_
# 127 tanayrathodd
# 128 etable_homekitchen
# 129 alexander_aaa_photo
# 130 elena.ferns
# 131 abhinavsinghmusic
# 132 priyamoni_143
# 133 thecake.factory
# 134 igothungryyy0708
# 135 vishal_jogal7
# 136 vedant.nanaware
# 137 andreeahealthy_food
# 138 p_i_y_u__sh143
# 139 aleem.saifi.35380
# 140 suganthipalanivel06
# 141 mymyt255
# 142 f.r.i.e.n.d.s.k.i.t.c.h.e.n
# 143 imshrutisinghal
# 144 harleenw257
# 145 its_jhon_official_
# 146 simrank719
# 147 manormaverma69
# 148 nanditha_naveen
# 149 raskolnikov_2811
# 150 vasukhanna1210
# 151 blackphoto69
# 152 asimraza_
# 153 its_aayush0001
# 154 lifeofpratayasha
# 155 wanderosity
# 156 savio._.sebastian
# 157 nadia.muzi
# 158 vimudha_2108
# 159 anyfoodin
# 160 arjunrajpoot112
# 161 gajendra1497
# 162 igbmtreedo
# 163 shriya_srivastava62
# 164 nehaagujral
# 165 kanchan_seervi1
# 166 bhalaria_bombay
# 167 sumit_rathod_6655
# 168 harini__narayanan
# 169 one_is_to_one
# 170 mommytimesblog
# 171 padharoindia
# 172 harry420i
# 173 prabhatsingh1200
# 174 aayansh_chowadry_23
# 175 das_americas87
# 176 daddiemodi
# 177 tasty_wish
# 178 macarons_by_richa
# 179 04_shivangi_09
# 180 mi_siddhi11
# 181 abhichoudhary3989
# 182 shikha_9597
# 183 shyamandhania
# 184 nandinii_sharma.a
# 185 atm_delhi
# 186 thrilla_tee
# 187 ashaynashikkar
# 188 nevscuts102
# 189 bondadondareel
# 190 ssimrannmalhotra
# 191 urj.asviiii
# 192 chinmayee_acharya
# 193 jhawarmukul
# 194 deshi.king.1
# 195 bappi.sehgal
# 196 deepak_swaroop_
# 197 sweetpieces.in
# 198 i_52blue
# 199 ayushii_gadekar
# 200 ek_anjaanladki
# 201 sniper.amar
# 202 nawaab_jada011
# 203 likhita_neelesh
# 204 deepti_goel97
# 205 craftsandook
# 206 urbasicfoodie
# 207 banknifty_jackpot_with_neha_
# 208 manish_negi_3
# 209 tushki13b
# 210 shintu.shinthu
# 211 manjesh4160
# 212 jsmspsaini
# 213 fatlulus
# 214 niteshkumar968722021
# 215 arushi.0.3
# 216 vishu890k
# 217 gaganmehta46
# 218 muliksupriya00
# 219 anjuri_das
# 220 rohitsharma9179
# 221 harshita_5374
# 222 kridhas_kitchen
# 223 boys_jewellery_shop
# 224 drums_of_heaven
# 225 _purnima_banerjee_
# 226 dazzlesaher__
# 227 rahi.l1746
# 228 nikouuy
# 229 akshaykumar_live._
# 230 nilesh_phadtare_
# 231 _afreenk._
# 232 chylls_lounge
# 233 rampriyas
# 234 isatarcana
# 235 jaishreee01
# 236 kartikkishore117
# 237 vipsoniya23
# 238 y_ins_pi_ration
# 239 anshuman0555
# 240 texas.tower
# 241 sameer_haavakajhonka
# 242 janvis_amezing_foodblog
# 243 a_girl_from_delhi
# 244 nishmalhotra4511
# 245 shivamjhasab
# 246 kamblesachin78688
# 247 suguruian
# 248 russianslovevodka
# 249 sunitee_rajawat
# 250 shriyans_rout
# 251 dimpi_sonowal
# 252 _goodtastejourney_
# 253 devika.eshana
# 254 sarvjeet_raii
# 255 khurafaati_baba
# 256 being._photographer
# 257 manish_shah_denial_2424
# 258 wine_market.100
# 259 pavan_111999
# 260 _rkmishra_
# 261 sbasera20
# 262 fmedesheva
# 263 goyal2493
# 264 __trusted__heart
# 265 manjeet_belwal
# 266 foodwithtish
# 267 hangoutswithfood
# 268 endless_following7
# 269 believe_kc
# 270 bheem_4646
# 271 kedarbenjamin
# 272 _harshit_soni_05_
# 273 taste_with_manisha
# 274 transport_department_mh_01
# 275 malabar.fatehpuri
# 276 lovelyboys698
# 277 kalp.esh1542
# 278 hasnainsoomar
# 279 saplingofearth
# 280 love.baba10
# 281 udayskochar
# 282 hamdan.4275
# 283 shakigracy
# 284 dilshad_singer08
# 285 muthukalirajan
# 286 anudube1810
# 287 its_niidhii_05
# 288 v__i__j__a__y___m_a_ll_a_y__a
# 289 belgavi_subramanya
# 290 naviin_the_introvert
# 291 sudarshankatawate
# 292 etenswaad
# 293 sanjusharma2816
# 294 thekitchenclever
# 295 food.with.yumm
# 296 tanishqnasa
# 297 niharika_patlolla
# 298 ta.nvi__1072
# 299 bannu_heart_haker
# 300 vedikaasood
# 301 kelin_patel_114
# 302 megharajpal
# 303 ruchika_raut
# 304 raja_sahu_3030
# 305 sharun9139
# 306 random_guy_chaithu
# 307 _anuragjoshie
# 308 pinkugirii
# 309 anupagnanakan
# 310 shroddhinator
# 311 abhinaya_govindaraj_
# 312 jagdishsurvilla
# 313 ja4839630
# 314 deeksha410
# 315 muskaangoyal77
# 316 roselyne_riuu
# 317 shubhampatil1415_
# 318 kim_ishu
# 319 rashmi11
# 320 hungervox
# 321 potahto_kalooo
# 322 cooking_with_rajnii
# 323 kruthian
# 324 akhilasrinivas
# 325 ajay_augustine
# 326 themartianink
# 327 hungryhumansofindia
# 328 aastha_sukhija
# 329 merak_vadra
# 330 niga_meraki
# 331 soneyaverma
# 332 _siraj_afaque_
# 333 sunainab11
# 334 singh.rajandeep_manu
# 335 damoralpesh57
# 336 _sheikh_sinan
# 337 6012.irfan
# 338 shukla_abhay3705
# 339 vishal.rke1001
# 340 sub_bha_dip
# 341 adv_enturevacations
# 342 aryu_veriii89
# 343 tanumehra01
# 344 bohra5722
# 345 foodguideny
# 346 ridemopar
# 347 sandeepdhamale
# 348 itszaaru86
# 349 anshul_hadoliya_786
# 350 nbkfoodhome
# 351 prateek_u_h
# 352 shubhthakur782002
# 353 npsgdigital
# 354 nanobotsolutions
# 355 sonali07vyas
# 356 shubham__joshi16
# 357 zaifeenfeen
# 358 bihanipratiksha
# 359 _being__a_chef
# 360 trending__in_
# 361 bigjarkalimpong
# 362 rahul.kulkarni9
# 363 artsy.tastery
# 364 ___jaanki
# 365 createrofthoughts
# 366 vlogsscoopofficial
# 367 _house_of_taste_s_
# 368 nehaa_0205
# 369 curryease
# 370 kittanehahmad
# 371 ashwinprakash
# 372 lonkaforon
# 373 bhattnehajoshi
# 374 nirav__nir
# 375 agrawalvertika
# 376 food_paradise_sanju
# 377 imanishkumarpal
# 378 bakesburg.bakery
# 379 tusharluthra07
# 380 urmitas
# 381 s_i_d_d_h_u_1825
# 382 antus_world_12
# 383 seeratkaurp
# 384 bhoomipandya1112
# 385 raja27rk
# 386 balveerkashyap
# 387 _ankit_7___09
# 388 tom.roadies_fashions
# 389 akshaya_nimmala
# 390 tiwarisocial
# 391 _saru_dixit
# 392 imandeepmahey.99
# 393 e_k_t_a_v_e_r_m_a
# 394 rohanandhare22
# 395 rama.sanap555555
# 396 yashgaddhyan
# 397 keshavgarg_____0726
# 398 ig_neeraj_
# 399 choudharysaab2316
# 400 naveed_mankari_123
# 401 mayur_vilhekar
# 402 priyakaithwar
# 403 mr_jokar_mr_jokar
# 404 nagarecanteen
# 405 nehasachdeva29
# 406 rishabh_____malviya
# 407 curly6594
# 408 anantika.kohli
# 409 vinayakmalkapure
# 410 sb.gaming.3785
# 411 bhojanam_grahankaram
# 412 psofficial14
# 413 tandooritalkies
# 414 __ta_n_nu.__
# 415 the.wildhunger
# 416 __house_of_cakes
# 417 ria_mittal
# 418 soni.rupali29
# 419 shantasanathkumar
# 420 chanchalsingh_22
# 421 foodjinie
# 422 nirchaiworld
# 423 subudhiyasaswi
# 424 chandok.tanya
# 425 i_am_only_here_for_memesy
# 426 chatoraankit
# 427 mels_head_over_meals
# 428 mirza_ayan_ali
# 429 amarchandpagolu
# 430 srikantasaurabh
# 431 hetvi_k_b
# 432 35.kiajiang
# 433 nikitha_0912
# 434 cook_with_hashi
# 435 pankajburathoki
# 436 ovenfreshbite
# 437 tanisha_lawrene
# 438 cheta_n3136
# 439 caramel_in_my_heart
# 440 mariam_a_zaidi
# 441 _black3___
# 442 love_forgharkakhana
# 443 chirag_gorani
# 444 alabalakes
# 445 __.derik.masih.__
# 446 kaladi.kulcha
# 447 bushrababar96
# 448 creativeridz
# 449 adv_anas_nazar
# 450 chinky.gupta.58
# 451 feedmegud_
# 452 the.harpers.lane
# 453 kartik.arora.39
# 454 shirsath_shirsath_30
# 455 stocktrader_3335
# 456 meera_chotalia
# 457 amze433
# 458 therapeutic_cooking_
# 459 poonamgupta6291
# 460 firehouseofficially
# 461 kohlirajesh59
# 462 srish.pansari
# 463 vishdhingra
# 464 viral.vasani.180
# 465 mallikakohli5
# 466 jiaul_official_
# 467 hasmotak
# 468 ___trnado_gaming
# 469 shikha_pandey90
# 470 vishalgoutam20039
# 471 food_is_fule
# 472 raghuraghu8010
# 473 foodiemoodii
# 474 sudesh_shetty07
# 475 no_farmer_no_food_zindabaad
# 476 sanjanakatyal
# 477 sunny.shiva1212
# 478 shagunagrawal07
# 479 ramesh_style1
# 480 jasneet.kaur.1703
# 481 thefoodloftrishikesh
# 482 shivambatra
# 483 freedombantai808
# 484 raveenaahuja7
# 485 fresh_facts99
# 486 tadka.live
# 487 modern_crockery
# 488 ___dhrub_gupta_84
# 489 itsavyakta
# 490 rohittt_08_71
# 491 farhancreative01
# 492 hinalthakkar
# 493 bipin.chatraliya0909
# 494 lion_hearted176
# 495 divabhansali
# 496 neha030
# 497 shailyparmar
# 498 debrakentjohnson
# 499 _satanese
# 500 p.tharunkrishna

# %% [markdown]
# ##### First 500 followers of ‘sodelhi’

# %%
#for search and open 'sodelhi' instagram handle
search_open_profile('sodelhi')

# %%
# Extracting followers using Extract_Followers() function
users = Extract_Followers()
ind = 1
for username in users:
    print(ind,username)
    ind += 1
# Out:
# 1 jagdeepkbadsiwal
# 2 the_jadoun
# 3 foodiefreak_gurugram
# 4 meera_pansuriya
# 5 deepali_singhal09
# 6 _alex_panda_
# 7 mansi_bahetii
# 8 priyaaaaanshiiii
# 9 khurram7370
# 10 himachal.in_
# 11 pikldbypushpa
# 12 vijayshreechoudharry
# 13 foodoutro
# 14 nancy__chopra
# 15 arpangarg001
# 16 pranay__ag
# 17 _jayesh_gangurde_
# 18 omairiftikhar
# 19 tushar_agarwal62
# 20 gurmeetsareen
# 21 nits_kalra
# 22 jasleenkaur1548
# 23 manojdukare123
# 24 i.prashantgupta
# 25 mahaskurdi
# 26 ankita5895
# 27 unlikesunshine
# 28 chamanwella
# 29 muskangupta2502
# 30 akauramrita
# 31 aisha.kodoruth
# 32 quotes_by_nitin
# 33 thisisarryan
# 34 mr_faizan_little_70
# 35 divya_0302
# 36 shubhamjai
# 37 nehu9999
# 38 grubshack_
# 39 gadsupriya
# 40 naveen_chander_joshi
# 41 cidraharismua.khi
# 42 krit.ikasethi
# 43 bestbookmart
# 44 official_ravijo
# 45 brownsugar_indirapuram
# 46 reetee_b
# 47 chubbyy_foodiee
# 48 _anushkamalik_
# 49 situbohra
# 50 sani_sii
# 51 pallaviaro
# 52 manav01nov
# 53 kanikaaa_rajput__singh9768
# 54 paintwithmegha
# 55 sharmasudeepti
# 56 singhankush_78
# 57 cookingwithrabi8071
# 58 _bbys7
# 59 divyanshukumar_ig
# 60 kshitijdhar
# 61 dhritirajani
# 62 me_noddy
# 63 shruti_shaw7890
# 64 singh.ihmshilpa17
# 65 chamandeep_3376
# 66 yadav_arun02
# 67 kya_jain_sahab
# 68 veeru_ji06
# 69 ariba.naeem
# 70 dayal_suyash4
# 71 pragya_chawla_
# 72 priyamtiwana
# 73 priyankabairagi4611
# 74 alfaz_e_arpit
# 75 unaisaaaaaaa
# 76 iamaribanaeem
# 77 raman.bhutani
# 78 kocharhim
# 79 deepa_shidnekoppa
# 80 i__zeeshankhan
# 81 maliksakshi_
# 82 anupriv___
# 83 canscenes
# 84 nivikaagarwal
# 85 dubey.ankur0
# 86 sarosh_akula
# 87 hiiissuppp
# 88 sonya.mehta06
# 89 licyayo_87
# 90 anushamarch
# 91 swadheagya
# 92 divyat_
# 93 mohammad_sami_88
# 94 rohit.shokeen.52438
# 95 sethisaab14
# 96 malinineshruth282027
# 97 jagrutishahhhh
# 98 mamatha_gowda_m.j
# 99 manansharma14
# 100 sunny_mha
# 101 tushita_ch
# 102 sumanmedage98
# 103 its_chiragg
# 104 harshxx_16
# 105 swati.prasad19
# 106 kinshuk_
# 107 ritika.chauhan99
# 108 muskan____sharma_______ji
# 109 mrfaisu075003
# 110 thekitcheninterio
# 111 navyanotnavyah
# 112 akspam.s
# 113 ainabharti
# 114 smritiarora06
# 115 harshk4704
# 116 allure.gold12
# 117 arshad4740
# 118 the_wordpainter
# 119 radhikalohia
# 120 the_kanishk_
# 121 mahi7781unofficial
# 122 yashita.mahajan
# 123 ashi_kapsons
# 124 priya__sharma__1401
# 125 silent_screm
# 126 anilmalik9719
# 127 monica.katyal
# 128 ayanna.miss_positive
# 129 gurjeetoberoi_29
# 130 savy_sadh
# 131 hsw0821
# 132 studiorudra
# 133 ek_ki_rani_
# 134 udit_0307
# 135 sharmamat_
# 136 shaileejauhari
# 137 lilmisspimple
# 138 kusum.kataria.562
# 139 riesha.manisha
# 140 motherdaughterduoo
# 141 officalbaldeep
# 142 _rishabhsarkar
# 143 officesumitbiswas
# 144 shrishtighai
# 145 hippieeebyheart
# 146 sumitibansal27
# 147 nyazayeka
# 148 tushargupta259
# 149 euphoricbloomss
# 150 ms_ur_way
# 151 foodiee_girl_23
# 152 gab08.23
# 153 govindpmundada
# 154 manormaverma69
# 155 just_being_myself_11
# 156 sanasiraj7860
# 157 mohitverma5865gmail.com_
# 158 ekta2279
# 159 hemantsahu44443
# 160 hemant6404
# 161 sonu92973
# 162 x_adityaaaaax
# 163 risshhbh
# 164 mishti_chhabra_
# 165 tanya22_
# 166 ronit0616
# 167 kkpl_theculinarylab
# 168 singh_shaab_01
# 169 _jessicathakur_
# 170 amodchaudhary27
# 171 itz_me_yuktesh
# 172 samruddhiparate
# 173 moose_bakku
# 174 gymlo_ver498
# 175 shreya_sassy001
# 176 maneeshreddy__
# 177 ias_paradise
# 178 pvtie.rk
# 179 sain._.i09
# 180 mansiisindhu_
# 181 sneha_pawar0706
# 182 ___call_____me____akhil_______
# 183 bhanot_pranav
# 184 tan._u__
# 185 vanshika4130
# 186 rmx_1404
# 187 rajatsenapati
# 188 vani.draws__
# 189 aditya_subham_official01
# 190 raashi.xo
# 191 vishrutii_shah
# 192 bwzhr4625
# 193 diarywriterr
# 194 mangeshwaghmare722
# 195 adesh_sinkar
# 196 ishaa_aa7
# 197 rufaaaana
# 198 zelhiboy
# 199 shubhambajaj17
# 200 achintk.jassal
# 201 x.arvind.choudhary
# 202 insta_followers_saler.10k
# 203 priyanshu.rohilla_07
# 204 adidas_clothes2
# 205 soyeahhwhateverr
# 206 essentio.in
# 207 welcome_to_kabir__city
# 208 high_hippogriff
# 209 ferryakhani
# 210 yourboy.sy
# 211 clumsy_girl001
# 212 rakeshroyrkd
# 213 joo_fernweh
# 214 samarth_3tyagi
# 215 nest__and_wings
# 216 inzimam_99
# 217 sahil.astro
# 218 pritika_15
# 219 foodies_bytes
# 220 sugambharti
# 221 bhupendra_07_
# 222 harshitjaain
# 223 totebag8448
# 224 o__suguru__zachery
# 225 sawawadop
# 226 mahakbatra
# 227 rishabhchaudhri
# 228 cuisinecultureee
# 229 vikas_5020_yadav
# 230 _naira_2549
# 231 ashok_bishnoi_781
# 232 ri_ya8623
# 233 ritesh_rai21
# 234 tanisha_shrivastav
# 235 riagupta001
# 236 madememoriesdecor
# 237 bhrdwj.ansh
# 238 signalphotosphere
# 239 readers_spot
# 240 sara.shinchan
# 241 minaakshi_7788
# 242 a_v_i_n_e_e_t
# 243 dashingturtle_wee
# 244 devil_nishant0006
# 245 pardeep_doon
# 246 p.a.l.l.a.b.i__d.a.s
# 247 rocknwoods.in
# 248 its_mehta6464
# 249 spambam5311
# 250 niranjankumar8849
# 251 simple_but_striking
# 252 harshu_sainiiii
# 253 potato_chips_00
# 254 genneyb
# 255 naiyapuri
# 256 skaterbhardwaj
# 257 pragsprivv
# 258 cuteboy9399
# 259 meet.chxdhx
# 260 oh_angga
# 261 navneetkaurkundi
# 262 karankonnect1
# 263 fernweh_diksha
# 264 adityasinhaha
# 265 happymealsagain_._
# 266 methlouthihathemi
# 267 haha.malang
# 268 asha_kaur16hs
# 269 nandita.singh1
# 270 shivanidolly257
# 271 asheyyy_27
# 272 maybeanurag
# 273 darkabhisekh
# 274 ankulgoel
# 275 vj_sontakke
# 276 nik0021
# 277 akash_dalal_07
# 278 pariiii_aroraaa
# 279 finney0011
# 280 sharunbajaj
# 281 narthurton11
# 282 thelodhigirl_
# 283 umaidtechie
# 284 diasmariaalves
# 285 jyoti.balhara07
# 286 surfeee
# 287 sahillakra_
# 288 s_sensebakery
# 289 shivikaachugh
# 290 rittikachhabra
# 291 idream_93
# 292 tube_steaknation
# 293 ramya_kandiboyina
# 294 aniiisha.pvt
# 295 ga_urav1656
# 296 jacqwill_
# 297 the_viper_rko123
# 298 himanigera.27
# 299 kunalsrivastv
# 300 afeefa215
# 301 cv__________________16
# 302 ehsanahmad191
# 303 __.snowy_secret.__5
# 304 lax.915
# 305 himanshuxlx
# 306 _._hunterrr
# 307 uday_surya19
# 308 foodiegazz
# 309 black_heart_creation_tn41
# 310 psyonara_earth
# 311 chetna.khurana
# 312 officialpreetraj
# 313 sparshhspam
# 314 subhasri.92
# 315 dinner_in_the_starlight
# 316 anubhuti.aroraa
# 317 charvisharmaaaa
# 318 poojajain_official_
# 319 kotwal.sakshi
# 320 seemasatija2
# 321 sakshi.khandelwal4
# 322 __ankitnikhil__
# 323 vaishnavi.aiyer
# 324 sunshine_flower88
# 325 ayush_shukla_3101
# 326 agra_delhi_ncr_play_boy
# 327 tossnights
# 328 dimpleee____queeennnn
# 329 sid_740
# 330 aaradhna_tyagi
# 331 nikitaa.n_
# 332 delhiicious_foodblogs
# 333 neha.a.a.a.a.a
# 334 sarabjeet.kalsi
# 335 bupeshh
# 336 mr_siryash_dhangar_8821
# 337 m4masala
# 338 vyyadav9211
# 339 j_shrey
# 340 sehaj007
# 341 kulkarniv537
# 342 dhruvj98
# 343 vandana999999
# 344 keen_sheetal
# 345 prasantasaha911
# 346 happiness__alive
# 347 vp.bakshi
# 348 thanabal1861989
# 349 ketul1147
# 350 nigamanshul
# 351 pasi5114
# 352 footribucket
# 353 krishnap4426
# 354 shashwat.kamboj.125
# 355 waffley_sweet_
# 356 perksofbeingpragya
# 357 srishh97
# 358 gdkt27
# 359 supe.rstar567
# 360 shrutimalikk
# 361 abhii_khatri
# 362 esharishabjain
# 363 sapnaguptagarg
# 364 phiwehintsa
# 365 shalimarwoods
# 366 kumaronjourney
# 367 heba_parveen
# 368 allthingscute.in
# 369 shrishti_leo
# 370 chitra12344
# 371 0414riya
# 372 akshitajain1411
# 373 niks_bakes
# 374 the.faheemkhan
# 375 khanalisha396
# 376 kirtibhushan_kb_
# 377 saniachadha
# 378 jolly_varnika_1116
# 379 saood_pathan
# 380 buff_traveller
# 381 awesome_arpit_31_
# 382 ipshita.gupta111
# 383 __ankita_goyal__
# 384 tajinderkaur.bhatia.52
# 385 preshna_gurl
# 386 ram_ya_red_dy
# 387 shefaleejo
# 388 real.food.on.reel
# 389 i_rashiarora
# 390 pratiksha_mane6
# 391 ashish.1604
# 392 an7ul
# 393 tushar_rajora_
# 394 mohammad.honarsazan
# 395 dhruvsharma.31
# 396 vidhushihisaria
# 397 rashibehal
# 398 _samaritasanjana_
# 399 deepti_agastya
# 400 wick_ed_shani
# 401 hamz_a6044
# 402 rauniqua_bisht
# 403 imjaiswal98
# 404 ad_astra_.13
# 405 gangster__hunter
# 406 ann_nellackal_
# 407 bunheadz_uk
# 408 shivammjain
# 409 void_uttu
# 410 ishant_v1.0
# 411 sandhyamalhotra22
# 412 sagarikathapar
# 413 chaii.pvt_
# 414 subhash_ydv
# 415 ishangogia1988
# 416 meenakajar
# 417 akasundeep
# 418 meghna_rawat04
# 419 kasif95
# 420 the_cake_dip
# 421 zaniyalit
# 422 anushkarastogi98
# 423 vanshita._.tuli
# 424 shrey.a1882
# 425 ishannmittal
# 426 kunal_rustagi8
# 427 renitabhuyan
# 428 as.ha4400
# 429 himanimanchanda02
# 430 tanveer_kahlon04
# 431 madanpooja
# 432 bhardwaj_07
# 433 kartik_brahman08
# 434 _._donita_._
# 435 j_yothika
# 436 chhayasonii
# 437 _aditiijain
# 438 angelheart1018
# 439 puneetmehraa
# 440 memayankagarwal
# 441 poojakoli7373
# 442 nandita.joshi.5074

# %% [markdown]
# #####  Print all the followers of “foodtalkindia” that you are following but those who don’t follow you.

# %%
def Following():
    try :
        # locating following button and click on it
        followers_btn = wait.until(EC.presence_of_all_elements_located((By.CLASS_NAME,'-nal3')))
        followers_btn[2].click()
        
        #locating followers list
        frame = driver.find_element_by_class_name('isgrP')
        #scrolling untill all users are located
        for i in range(20):
            time.sleep(1)
            driver.execute_script("arguments[0].scrollTop=arguments[0].scrollHeight",frame)
        
        names = []
        #extracting userdata
        following = driver.find_elements_by_class_name('enpQJ')
        #extracting username
        for i in following :
                names.append(i.text.split('\n')[0])
            
        return names
    except TimeoutException :
        print("Something Went Wrong!")

# %%
#for search and open 'foodtalkindia' instagram handle
search_open_profile('foodtalkindia')
# Extracting followers using Extract_Followers() function
followers_of_foodtalkind = Extract_Followers()
#casting into set
followers_of_foodtalkind = set(followers_of_foodtalkind)

# %%
#now finding all user followed by me for that I'll use search_open_profile() after that using Following() I will extrat all user
#followed by me
search_open_profile(username)
followed_by_me = Following()
followed_by_me = set(followed_by_me)

# %%
#taking intersection so s1 contains only that user who followed by me
s1=(followers_of_foodtalkind).intersection(followed_by_me)
if len(s1) == 0:
    print('No such users found')
else:
    #now extracting my followers
    my_followers = Extract_Followers()
    my_followers = set(my_follower)
    #taking intersection with s1, so s2 contains only users that I am following them but they don’t follow me
    s2=s1.intersection(my_followers)
    if len(s2) == 0:
        print('No such users found')
    else:
        for user in s2:
            print(user)
# Out:
# No such users found

# %% [markdown]
# ### Problem 7 : Check the story of ‘coding.ninjas’
# Check the story of ‘coding.ninjas’. Consider the following Scenarios and print error messages accordingly -
# 1.If You have already seen the story.
# 2.Or The user has no story.
# 3.Or View the story if not yet seen.

# %%
def Check_Story():
    try:
        #locating story or profile pic
        story = wait.until(EC.presence_of_element_located((By.CLASS_NAME,"CfWVH")))
    
        #check the Profile photo size to find out story is available or not
        height = driver.find_element_by_class_name('CfWVH').get_attribute('height')
        if int(height) == 131:
            print("Already Seen")
        else:
            print("Viewing the story")
            driver.execute_script("arguments[0].click();",story)
    except:
        print("No story available")

# %%
#searching 'coding.ninjas' using search_open_profile() function
search_open_profile('coding.ninjas')

# %%
#for checking story
Check_Story()
# Out:
# Viewing the story
